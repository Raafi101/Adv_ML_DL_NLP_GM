# %% [markdown]
# #Statistics 72556
#
# ###Imports

# %%
#!pip install dtale

# %%
import numpy as np
import pandas as pd

import dtale

import tensorflow as tf
from sklearn.linear_model import LinearRegression
